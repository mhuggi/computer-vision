# %%
import matplotlib.pyplot as plt
import cv2 as cv

from keras.preprocessing.image import ImageDataGenerator

# %%
img_gen = ImageDataGenerator(rotation_range=30,
                            width_shift_range=0.1,
                            height_shift_range=0.1,
                            rescale=1/255,
                            zoom_range=0.2,
                            horizontal_flip=True)

# %%
train_img_gen = img_gen.flow_from_directory('PetImages',
                                           target_size=(200,200))
# Out:
# Found 24997 images belonging to 2 classes.

# %%
train_img_gen.class_indices
# Out:
# {'Cat': 0, 'Dog': 1}

# %%
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.optimizers import SGD

# %%
model = Sequential()
model.add(Conv2D(32, (3,3), input_shape = (200,200,3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Conv2D(64, (3,3), input_shape = (200,200,3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Conv2D(128, (3,3), input_shape = (200,200,3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Flatten())
model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(units = 2, activation = "sigmoid"))

# %%
opt = SGD(lr=0.001, momentum=0.9)
model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 198, 198, 32)      896
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 99, 99, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 97, 97, 64)        18496
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 48, 48, 64)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 46, 46, 128)       73856
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 23, 23, 128)       0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 67712)             0
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               8667264
# _________________________________________________________________
# dense_10 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 8,760,770
# Trainable params: 8,760,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
results = model.fit(train_img_gen, epochs=20)
# Out:
# Epoch 1/20
# 782/782 [==============================] - 622s 794ms/step - loss: 0.6851 - accuracy: 0.5459
# Epoch 2/20
# 782/782 [==============================] - 528s 674ms/step - loss: 0.6563 - accuracy: 0.6028
# Epoch 3/20
# 782/782 [==============================] - 526s 672ms/step - loss: 0.6275 - accuracy: 0.6453
# Epoch 4/20
# 782/782 [==============================] - 519s 663ms/step - loss: 0.5978 - accuracy: 0.6769
# Epoch 5/20
# 782/782 [==============================] - 527s 673ms/step - loss: 0.5768 - accuracy: 0.6934
# Epoch 6/20
# 782/782 [==============================] - 524s 669ms/step - loss: 0.5605 - accuracy: 0.7083
# Epoch 7/20
# 782/782 [==============================] - 519s 664ms/step - loss: 0.5558 - accuracy: 0.7079
# Epoch 8/20
# 782/782 [==============================] - 518s 662ms/step - loss: 0.5389 - accuracy: 0.7199
# Epoch 9/20
# 782/782 [==============================] - 519s 663ms/step - loss: 0.5215 - accuracy: 0.7410
# Epoch 10/20
# 782/782 [==============================] - 519s 663ms/step - loss: 0.5130 - accuracy: 0.7486
# Epoch 11/20
# 782/782 [==============================] - 519s 663ms/step - loss: 0.4976 - accuracy: 0.7596
# Epoch 12/20
# 782/782 [==============================] - 519s 664ms/step - loss: 0.4964 - accuracy: 0.7571
# Epoch 13/20
# 782/782 [==============================] - 518s 662ms/step - loss: 0.4875 - accuracy: 0.7611
# Epoch 14/20
# 782/782 [==============================] - 519s 663ms/step - loss: 0.4691 - accuracy: 0.7733
# Epoch 15/20
# 782/782 [==============================] - 520s 664ms/step - loss: 0.4725 - accuracy: 0.7721
# Epoch 16/20
# 782/782 [==============================] - 520s 664ms/step - loss: 0.4622 - accuracy: 0.7784
# Epoch 17/20
# 782/782 [==============================] - 589s 753ms/step - loss: 0.4530 - accuracy: 0.7849
# Epoch 18/20
# 782/782 [==============================] - 594s 759ms/step - loss: 0.4448 - accuracy: 0.7958
# Epoch 19/20
# 782/782 [==============================] - 588s 751ms/step - loss: 0.4357 - accuracy: 0.7974
# Epoch 20/20
# 782/782 [==============================] - 525s 670ms/step - loss: 0.4321 - accuracy: 0.7973

# %%
plt.plot(results.history['accuracy'])

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing import image
test_img = 'media/luna2.jpg'
test_img = image.load_img(test_img, target_size=(200,200))
test_img = image.img_to_array(test_img)

test_img = np.expand_dims(test_img, axis=0)
test_img = test_img/255

# %%
import matplotlib.image as mpimg
img = mpimg.imread('media/luna2.jpg')
plt.imshow(img)

# %% [markdown]
# ## Not really sure what happened here, image load is probably incorrect

# %%
prob = model.predict(test_img)
prob
# Out:
# array([[0.53573364, 0.48559165]], dtype=float32)

# %%
print("Cat:" + str(prob[0][0]))
print("Dog:" + str(prob[0][1]))
# Out:
# Cat:0.53573364
# Dog:0.48559165

# %%
train_img_gen = img_gen.flow_from_directory('PetImages',
                                           target_size=(100,100))
train_img_gen.class_indices
model = Sequential()
model.add(Conv2D(32, (3,3), input_shape = (100,100,3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Flatten())
model.add(Dense(units = 2, activation = "sigmoid"))
model.compile(optimizer = 'adam',
             loss = 'binary_crossentropy',
             metrics = ['accuracy'])
results = model.fit(train_img_gen, epochs=20)
# Out:
# Found 24997 images belonging to 2 classes.
# Epoch 1/20
# 782/782 [==============================] - 100s 128ms/step - loss: 0.7246 - accuracy: 0.6008
# Epoch 2/20
# 782/782 [==============================] - 99s 126ms/step - loss: 0.6078 - accuracy: 0.6712
# Epoch 3/20
# 782/782 [==============================] - 99s 126ms/step - loss: 0.5776 - accuracy: 0.7018
# Epoch 4/20
# 782/782 [==============================] - 99s 126ms/step - loss: 0.5838 - accuracy: 0.6940
# Epoch 5/20
# 782/782 [==============================] - 99s 126ms/step - loss: 0.5756 - accuracy: 0.7028
# Epoch 6/20
# 782/782 [==============================] - 99s 126ms/step - loss: 0.5678 - accuracy: 0.7042
# Epoch 7/20
# 782/782 [==============================] - 98s 126ms/step - loss: 0.5707 - accuracy: 0.7034
# Epoch 8/20
# 782/782 [==============================] - 99s 126ms/step - loss: 0.5653 - accuracy: 0.7117
# Epoch 9/20
# 782/782 [==============================] - 98s 125ms/step - loss: 0.5601 - accuracy: 0.7142
# Epoch 10/20
# 782/782 [==============================] - 98s 125ms/step - loss: 0.5521 - accuracy: 0.7261
# Epoch 11/20
# 782/782 [==============================] - 98s 125ms/step - loss: 0.5551 - accuracy: 0.7195
# Epoch 12/20
# 782/782 [==============================] - 98s 126ms/step - loss: 0.5556 - accuracy: 0.7253
# Epoch 13/20
# 782/782 [==============================] - 98s 126ms/step - loss: 0.5526 - accuracy: 0.7220
# Epoch 14/20
# 782/782 [==============================] - 98s 125ms/step - loss: 0.5456 - accuracy: 0.7216
# Epoch 15/20
# 782/782 [==============================] - 98s 126ms/step - loss: 0.5495 - accuracy: 0.7228
# Epoch 16/20
# 782/782 [==============================] - 98s 125ms/step - loss: 0.5535 - accuracy: 0.7215
# Epoch 17/20
# 782/782 [==============================] - 98s 126ms/step - loss: 0.5531 - accuracy: 0.7187
# Epoch 18/20
# 782/782 [==============================] - 97s 124ms/step - loss: 0.5426 - accuracy: 0.7238
# Epoch 19/20
# 782/782 [==============================] - 97s 124ms/step - loss: 0.5598 - accuracy: 0.7164
# Epoch 20/20
# 782/782 [==============================] - 97s 124ms/step - loss: 0.5455 - accuracy: 0.7296

# %%
plt.plot(results.history['accuracy'])
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing import image
test_img = 'media/luna2.jpg'
test_img = image.load_img(test_img, target_size=(100,100))
test_img = image.img_to_array(test_img)

test_img = np.expand_dims(test_img, axis=0)
test_img = test_img/255

# %%
prob = model.predict(test_img)
print("Cat:" + str(prob[0][0]))
print("Dog:" + str(prob[0][1]))
# Out:
# WARNING:tensorflow:7 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001FE8DFAA940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Cat:0.024443
# Dog:0.9775876

# %%
train_img_gen = img_gen.flow_from_directory('PetImages',
                                           target_size=(64,64))
train_img_gen.class_indices
model = Sequential()
model.add(Conv2D(32, (3,3), input_shape = (64,64,3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Flatten())
model.add(Dense(units = 2, activation = "sigmoid"))
model.compile(optimizer = 'adam',
             loss = 'binary_crossentropy',
             metrics = ['accuracy'])
results = model.fit(train_img_gen, epochs=5)
# Out:
# Found 24997 images belonging to 2 classes.
# Epoch 1/5
# 782/782 [==============================] - 60s 76ms/step - loss: 0.6654 - accuracy: 0.5935
# Epoch 2/5
# 782/782 [==============================] - 59s 76ms/step - loss: 0.5916 - accuracy: 0.6852
# Epoch 3/5
# 782/782 [==============================] - 59s 76ms/step - loss: 0.5813 - accuracy: 0.6924
# Epoch 4/5
# 782/782 [==============================] - 59s 76ms/step - loss: 0.5712 - accuracy: 0.7034
# Epoch 5/5
# 782/782 [==============================] - 59s 76ms/step - loss: 0.5654 - accuracy: 0.7058

# %%
plt.plot(results.history['accuracy'])
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing import image
test_img = 'media/luna2.jpg'
test_img = image.load_img(test_img, target_size=(64,64))
test_img = image.img_to_array(test_img)

test_img = np.expand_dims(test_img, axis=0)
test_img = test_img/255

# %%
prob = model.predict(test_img)
print("Cat:" + str(prob[0][0]))
print("Dog:" + str(prob[0][1]))
# Out:
# WARNING:tensorflow:8 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001FE91857280> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Cat:0.0147281885
# Dog:0.98450506

# %%
# save the final model to file
from keras.applications.vgg16 import VGG16
from keras.models import Model
from keras.layers import Dense
from keras.layers import Flatten
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator

# define cnn model
def define_model():
	# load model
	model = VGG16(include_top=False, input_shape=(224, 224, 3))
	# mark loaded layers as not trainable
	for layer in model.layers:
		layer.trainable = False
	# add new classifier layers
	flat1 = Flatten()(model.layers[-1].output)
	class1 = Dense(128, activation='relu', kernel_initializer='he_uniform')(flat1)
	output = Dense(1, activation='sigmoid')(class1)
	# define new model
	model = Model(inputs=model.inputs, outputs=output)
	# compile model
	opt = SGD(lr=0.001, momentum=0.9)
	model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
	return model

# run the test harness for evaluating a model
def run_test_harness():
# define model
	model = define_model()
	# create data generator
	datagen = ImageDataGenerator(featurewise_center=True)
	# specify imagenet mean values for centering
	datagen.mean = [123.68, 116.779, 103.939]
	# prepare iterator
	train_it = datagen.flow_from_directory('PetImages/',
		class_mode='binary', batch_size=64, target_size=(224, 224))
	# fit model
	model.fit_generator(train_it, steps_per_epoch=len(train_it), epochs=10, verbose=0)
	# save model
	model.save('final_model.h5')

# entry point, run the test harness
run_test_harness()
# Out:
# Found 24997 images belonging to 2 classes.
# C:\Users\Mhuggi\anaconda3\envs\opencv\lib\site-packages\tensorflow\python\keras\engine\training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# C:\Users\Mhuggi\anaconda3\envs\opencv\lib\site-packages\PIL\TiffImagePlugin.py:771: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32 bytes but only got 0. Skipping tag 270
#   warnings.warn(
# C:\Users\Mhuggi\anaconda3\envs\opencv\lib\site-packages\PIL\TiffImagePlugin.py:771: UserWarning: Possibly corrupt EXIF data.  Expecting to read 5 bytes but only got 0. Skipping tag 271
#   warnings.warn(
# C:\Users\Mhuggi\anaconda3\envs\opencv\lib\site-packages\PIL\TiffImagePlugin.py:771: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 272
#   warnings.warn(
# C:\Users\Mhuggi\anaconda3\envs\opencv\lib\site-packages\PIL\TiffImagePlugin.py:771: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 282
#   warnings.warn(
# C:\Users\Mhuggi\anaconda3\envs\opencv\lib\site-packages\PIL\TiffImagePlugin.py:771: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 283
#   warnings.warn(
# C:\Users\Mhuggi\anaconda3\envs\opencv\lib\site-packages\PIL\TiffImagePlugin.py:771: UserWarning: Possibly corrupt EXIF data.  Expecting to read 20 bytes but only got 0. Skipping tag 306
#   warnings.warn(
# C:\Users\Mhuggi\anaconda3\envs\opencv\lib\site-packages\PIL\TiffImagePlugin.py:771: UserWarning: Possibly corrupt EXIF data.  Expecting to read 48 bytes but only got 0. Skipping tag 532
#   warnings.warn(
# C:\Users\Mhuggi\anaconda3\envs\opencv\lib\site-packages\PIL\TiffImagePlugin.py:793: UserWarning: Corrupt EXIF data.  Expecting to read 2 bytes but only got 0.
#   warnings.warn(str(msg))

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.models import load_model

# load and prepare the image
def load_image(filename):
	# load the image
	img = load_img(filename, target_size=(224, 224))
	# convert to array
	img = img_to_array(img)
	# reshape into a single sample with 3 channels
	img = img.reshape(1, 224, 224, 3)
	# center pixel data
	img = img.astype('float32')
	img = img - [123.68, 116.779, 103.939]
	return img

# load an image and predict the class
def run_example():
    # load the image
    img = load_image('media/luna2.jpg')
    # load model
    model = load_model('final_model.h5')
    # predict the class
    result = model.predict(img)
    print("Cat: ", result[0][0])
    print("Dog: ", 1 - result[0][0])

# entry point, run the example
run_example()
# Out:
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000022C0E0A4C10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Cat:  0.0014841557
# Dog:  0.9985158443450928
