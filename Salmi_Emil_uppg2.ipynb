# %%
from matplotlib import pyplot as plt
import matplotlib.image as mpimg
import numpy
import cv2 as cv

img1 = cv.imread("foggy.jpg", 0)
img2 = cv.imread("tree1.jpg", 0)
img3 = cv.imread("tree2.jpg", 0)

if img1 is None:
    sys.exit("Could not read the image.")
else:
    cv.imshow("img1",img1)
    cv.waitKey(0)
    cv.destroyAllWindows()

# %%
fig, axs = plt.subplots(2, 2)

axs[0,0].hist(img1.flatten(),256,[0,256], color='r')
img1_eq = cv.equalizeHist(img1)
axs[1,0].hist(img1_eq.flatten(),256,[0,256], color='r')
axs[0,1].imshow(img1, cmap="gray")
axs[1,1].imshow(img1_eq, cmap="gray")
plt.show()

# %%
fig, axs = plt.subplots(2, 2)

axs[0,0].hist(img2.flatten(),256,[0,256], color='r')
img2_eq = cv.equalizeHist(img2)
axs[1,0].hist(img2_eq.flatten(),256,[0,256], color='r')
axs[0,1].imshow(img2, cmap="gray")
axs[1,1].imshow(img2_eq, cmap="gray")
plt.show()

# %%
fig, axs = plt.subplots(2, 2)

axs[0,0].hist(img3.flatten(),256,[0,256], color='r')
img3_eq = cv.equalizeHist(img3)
axs[1,0].hist(img3_eq.flatten(),256,[0,256], color='r')
axs[0,1].imshow(img3, cmap="gray")
axs[1,1].imshow(img3_eq, cmap="gray")
plt.show()

# %%
img4 = cv.imread("chess.jpg", 0)
fig, axs = plt.subplots(2, 2)

axs[0,0].hist(img4.flatten(),256,[0,256], color='r')
img4_eq = cv.equalizeHist(img4)
axs[1,0].hist(img4_eq.flatten(),256,[0,256], color='r')
axs[0,1].imshow(img4, cmap="gray")
axs[1,1].imshow(img4_eq, cmap="gray")
plt.show()

# %% [markdown]
# # Report
# All equalizers seem to work very well and the images are clear. especially the last image.
#
# For the chess board the equalizer doesn't really do much as it is already pretty equalized and no big spikes in the histogram.
